# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranjith5720/Regression_Models/blob/main/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Import Necessary Libraries :**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Data On-Boarding :**

# %%
# Upload raw dataset

from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-0b488574-80a6-45c9-9295-1477f4baa0bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b488574-80a6-45c9-9295-1477f4baa0bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Convert raw dataset to dataframe

df = pd.read_csv('tvmarketing.csv')
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %% [markdown]
# ### **Data Preprocessing :**
#
# - Data Preprossing is a the process of cleaning and preparing raw data before used for modeling and analysis.
#
# **Types :**
#
# - Exploratory Data Analysis ( EDA )
# - Data Cleaning
# - Data Encoding

# %% [markdown]
# #### **Exploratry Data Analysis : ( EDA )**
#
# - Exploratory Data Analysis ( EDA ) is the process that analyzes and summarizes datasets to identify patterns, relationships, and characteristics.
#
# - It is a crucial first step in any machine learning or data analysis project.
#
# **Techniques :**
#
# - **Descriptive Statistical Analysis :**
# Calculating descriptive statistical analysis, such as : mean, median, Standard Deviation, etc.
#
# - **Data Visualization :**
# Use any graphs to visualize the data base on the dataset. such as,  histogram, scatter plot, boxplot, etc.
#
# - **Missing Values :**
# Find the missing values in the dataset.
#
# - **Outliers :**
# Find the outliers in the dataset.

# %%
# Find the Total no. of rows and columns in the dataframe

df.shape
# Out:
# (200, 2)

# %%
# Find the column names in the dataframe

df.columns
# Out:
# Index(['TV', 'Sales'], dtype='object')

# %%
# find first 5 rows in the dataframe

df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
# find last 5 rows in the dataframe

df.tail()
# Out:
#         TV  Sales
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4

# %%
# All informations about the  given dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
# Descriptive statistical analysis

df.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
# Find the missing values in the dataframe

df.isnull().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
# find outliers in the independent variable
sns.set_theme()
sns.boxplot(data=df,orient='h')
# Out:
# <Axes: >

# %%
sns.jointplot(x='TV', y='Sales', data= df, kind='reg', color='m')

# %% [markdown]
# #### **Data Cleaning :**
#
# - Data cleaning is the process of identifying and removing outliers, correcting errors, missing values in the dataset.
#
# - There is no outliers and missining values in the dataframe. So, no need to data cleaning process.

# %% [markdown]
# #### **Label Encoding :**
#
# - Data encoding is the process of converting data from one format to another, that can be understood by a machine learning algorithm. Mostly machine learning algorithms can only work with numerical data.
#
# - There is no categorical data in the dataframe. so, no need to label encoding process.

# %% [markdown]
# #### **X & Y Split :**
#
# - X is a matrix of feature values. It is also known as input, feature set, or independent variables.
#
# - Y is a vector of target values. It is also known as target, class, or label.
#
# ![image.png](data:image/png;base64,...)

# %%
# Separate the Indepentend variable in the dataframe

x = df.iloc[:,:-1]
x
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
# @title TV

df['TV'].plot(kind='hist', bins=20, title='TV')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Separate the Depentend (target) variable in the dataframe

y = df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# @title Sales

from matplotlib import pyplot as plt
df['Sales'].plot(kind='hist', bins=20, title='Sales')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title TV vs Sales

plt.scatter(x,y)
plt.title('TV Marketing')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# **Train & Test Split :**
#
# - Split the dataset into train and test sets.

# %%
# @title Split the train & test data

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=1/3,random_state=7)

# %%
x_train.shape, x_test.shape
# Out:
# ((133, 1), (67, 1))

# %%
y_train.shape, y_test.shape
# Out:
# ((133,), (67,))

# %% [markdown]
# ### **Model Building :**
#
# - Model building is the process of creating a model to read the data and make predictions or decisions.
#
# - It is build using a set if training data.

# %% [markdown]
# **Simple Linear Regresion :**
#
# - Simple linear regression is a statistical method uses only one independent variable to predict a single dependent ( target or y ) variable.
#
# **Formula :**
#
# - **y = m x + c**
# ( default value of m = 1 and c = 0 )
# y - is the dependent variable
# x - is the independent variable
# m - is the bias
# c - is the constant
#
#  ![image.png](data:image/png;base64,...)

# %%
# import linear regression model

from sklearn.linear_model import LinearRegression
slr = LinearRegression()

# %%
# train the model

slr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# find predicted value

y_predict = slr.predict(x_test)
y_predict
# Out:
# array([10.89474827, 13.90639341,  7.97113583, 17.30723577,  9.12946089,
#         8.15646784,  8.23060064, 12.33570463,  8.81902977, 12.11793952,
#         7.96650253, 16.51494143,  9.3518593 , 10.55651735, 20.61077882,
#         7.54950551, 10.24608624, 13.6237621 , 15.29638347, 11.5156105 ,
#        20.1798819 , 15.9265123 , 12.20597223, 17.24700286, 13.822994  ,
#        20.53201272, 21.09264204, 15.56048159, 19.19298896, 15.24541717,
#        13.6700951 ,  8.51786526, 15.35198308, 17.25163616, 17.9929642 ,
#        16.31107622,  7.72093762, 20.68491162, 10.89938157, 13.8090941 ,
#        10.12098713, 17.56670058,  9.83835582, 17.73813269, 18.48409402,
#        16.74197314, 15.47244888, 10.85768187, 12.59053615, 16.06087801,
#        11.86310801, 11.87700791, 10.89938157,  7.60973841, 19.64705238,
#        18.88719114, 10.56578395, 16.33424272,  9.06922798, 15.9265123 ,
#        11.45074429, 17.12653706, 17.07093746,  9.4306254 , 19.72581848,
#         8.15646784,  9.96345492])

# %%
# Visualisation of predicted model

plt.scatter(x_train,y_train)
plt.plot(x_test,y_predict,c='red')
plt.title('TV Marketing')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# #### **Model Evaluation :**
#
# - Model evaluation is the process of evaluate the performance of a model on a separate set of data test data.

# %%
# import evaluation metrics for regression model

from sklearn.metrics import r2_score,mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,mean_squared_log_error

# %% [markdown]
# **Coefficient of Determination ( R - Squared ) :**
#
# - R - Squared measures the proportion of the variance in the dependent variable that is predictable from the independent variables.
#
# - It ranges from 0 to 1, with higher values indicating a better fit of the model to the data.
#
#  ![image.png](data:image/png;base64,...)

# %%
# find r_squared value

r2 = r2_score(y_test, y_predict) # r^2 = 1 - np.var(y_test - y_predict) / np.var(y_test)
r2
# Out:
# 0.66339568124155

# %% [markdown]
# **Adjusted R - Squared :**
#
# - Adjusted R-squared is a modified version of R - Squared that adjusts for the number of predictors in the model.
#
# - It penalizes the addition of unnecessary predictors.

# %%
# find adjusted r_squared value

adjusted_r2 = 1 - ((1 - r2) * (len(x) - 1)) / (len(x) - x.shape[1] - 1)
adjusted_r2
# Out:
# 0.6616956594296386

# %% [markdown]
# **Mean Absolute Error ( MAE ) :**
#
# - MAE measures the average absolute difference between the predicted values and the actual values.
#
# - It is calculated as the average of the absolute differences between predicted and actual values.
#
#  ![image.png](data:image/png;base64,...)

# %%
# find mean absolute error value

MAE = mean_absolute_error(y_test,y_predict) # MAE = np.mean(np.abs(y_test - y_predict))
MAE
# Out:
# 2.287293713748798

# %% [markdown]
# **Mean Squared Error ( MSE ) :**
#
# - MSE measures the average squared difference between the predicted values and the actual values.
#
# - It penalizes large errors more than smaller ones.
#
#  ![image.png](data:image/png;base64,...)

# %%
# find mean squared error value

MSE = mean_squared_error(y_test,y_predict) # MSE = np.mean(np.square(y_test - y_predict))
MSE
# Out:
# 9.170409368379852

# %% [markdown]
# **Mean Squared Error ( RMSE ) :**
#
# - RMSE is the square root of the MSE.
#
# - It is in the same unit as the dependent variable, making it easier to interpret.
#
#  ![image.png](data:image/png;base64,...)

# %%
# find root mean squared error value

RMSE = np.sqrt(MSE)
RMSE
# Out:
# 3.0282683778654516

# %% [markdown]
# **Mean Absolute Percentage Error ( MAPE ) :**
#
# - MAPE measures the average percentage difference between the predicted and actual values.
#
# - It is useful when the scale of the data varies widely.
#
#  ![image.png](data:image/png;base64,...)

# %%
MAPE = mean_absolute_percentage_error(y_test,y_predict)
MAPE
# Out:
# 0.1966968956427862

# %% [markdown]
# #### **Conclusion :**
#
# - Using simple linear regression model for this problem.
# - Evaluate the model to get  r_squared value is 0.663
# - Based on r_squared value the model is fit for this problem.
